# %% [markdown]
# # 1. Customer Behavior Analytics (Task 1)

# %%
# import all relevant libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
sns.set()


sns.set_style("white")
sns.set_palette("GnBu_d")

# also import these "new" libraries 
# Note: you may have to download an add them to your environment (using e.g. 'conda install -c conda-forge folium')

import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime #for working with times objects
from datetime import timedelta #for working with times objects
import math
import random
#import timeit

# %% [markdown]
# ## 1.1 Bike Dataset

# %% [markdown]
# Reading in the **bike dataset** and performing some basic operations

# %%
PHL_17 = pd.read_csv("PHL_2017.csv", encoding = "ISO-8859-1")
PHL_17.sort_values("start_time", inplace = True)

# %%
PHL_17.head()
# Out:
#       start_time       end_time  start_station_id  end_station_id  bike_id  \
# 0  1/1/2017 0:05  1/1/2017 0:16              3046            3041     5347
# 1  1/1/2017 0:21  1/1/2017 0:57              3110            3054     3364
# 2  1/1/2017 0:22  1/1/2017 0:57              3110            3054     2536
# 3  1/1/2017 0:27  1/1/2017 0:39              3041            3005     5176
# 4  1/1/2017 0:28  1/1/2017 0:36              3047            3124     5370
#
#   user_type           start_station_name     end_station_name
# 0  Indego30                 2nd & Market  Girard Station, MFL
# 1   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 2   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 3  Indego30          Girard Station, MFL    Welcome Park, NPS
# 4   Walk-up       Independence Mall, NPS     Race Street Pier

# %% [markdown]
# Changing datatype from string to **datetime** in order to make the dataframe **maskable**

# %%
PHL_17['start_time'] = pd.to_datetime(PHL_17['start_time'])
PHL_17['end_time'] = pd.to_datetime(PHL_17['end_time'])

# %%
PHL_17
# Out:
#                start_time            end_time  start_station_id  \
# 0     2017-01-01 00:05:00 2017-01-01 00:16:00              3046
# 1     2017-01-01 00:21:00 2017-01-01 00:57:00              3110
# 2     2017-01-01 00:22:00 2017-01-01 00:57:00              3110
# 3     2017-01-01 00:27:00 2017-01-01 00:39:00              3041
# 4     2017-01-01 00:28:00 2017-01-01 00:36:00              3047
# ...                   ...                 ...               ...
# 82772 2017-03-09 09:58:00 2017-03-09 10:55:00              3047
# 82773 2017-03-09 09:58:00 2017-03-09 10:35:00              3106
# 82776 2017-03-09 09:59:00 2017-03-09 10:55:00              3047
# 82774 2017-03-09 09:59:00 2017-03-09 17:00:00              3006
# 82775 2017-03-09 09:59:00 2017-03-09 10:06:00              3054
#
#        end_station_id  bike_id user_type           start_station_name  \
# 0                3041     5347  Indego30                 2nd & Market
# 1                3054     3364   Walk-up  Del. River Trail & Penn St.
# 2                3054     2536   Walk-up  Del. River Trail & Penn St.
# 3                3005     5176  Indego30          Girard Station, MFL
# 4                3124     5370   Walk-up       Independence Mall, NPS
# ...               ...      ...       ...                          ...
# 82772            3057     2475   Walk-up       Independence Mall, NPS
# 82773            3066     3510  Indego30               33rd & Dauphin
# 82776            3057     3630   Walk-up       Independence Mall, NPS
# 82774            3006     3497  Indego30                40th & Spruce
# 82775            3078     5293  Indego30                 Rodin Museum
#
#                  end_station_name
# 0             Girard Station, MFL
# 1                    Rodin Museum
# 2                    Rodin Museum
# 3               Welcome Park, NPS
# 4                Race Street Pier
# ...                           ...
# 82772  Philadelphia Museum of Art
# 82773              19th & Lombard
# 82776  Philadelphia Museum of Art
# 82774               40th & Spruce
# 82775               19th & Market
#
# [788907 rows x 8 columns]

# %%
PHL_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 788907 entries, 0 to 82775
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   start_time          788907 non-null  datetime64[ns]
#  1   end_time            788907 non-null  datetime64[ns]
#  2   start_station_id    788907 non-null  int64
#  3   end_station_id      788907 non-null  int64
#  4   bike_id             788907 non-null  int64
#  5   user_type           788907 non-null  object
#  6   start_station_name  788907 non-null  object
#  7   end_station_name    788907 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(3)
# memory usage: 54.2+ MB

# %%
PHL_17.describe()
# Out:
#        start_station_id  end_station_id        bike_id
# count     788907.000000   788907.000000  788907.000000
# mean        3057.400081     3056.431487    5428.980913
# std           41.126829       41.108792    3221.972215
# min         3000.000000     3000.000000       0.000000
# 25%         3023.000000     3023.000000    3350.000000
# 50%         3050.000000     3049.000000    3703.000000
# 75%         3075.000000     3074.000000    5370.000000
# max         3170.000000     3170.000000   11965.000000

# %% [markdown]
# Checking the bike dataset for **NULL values**

# %%
PHL_17[PHL_17.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, start_station_id, end_station_id, bike_id, user_type, start_station_name, end_station_name]
# Index: []

# %%
print(PHL_17.isnull().sum())
# Out:
# start_time            0
# end_time              0
# start_station_id      0
# end_station_id        0
# bike_id               0
# user_type             0
# start_station_name    0
# end_station_name      0
# dtype: int64

# %% [markdown]
# Seemingly no NULL values exist in the bike dataset

# %% [markdown]
# Let's add some **more features** to our dataset, in order to have some richer information

# %%
PHL_17['date'] = PHL_17['start_time'].dt.date
PHL_17['hour'] = PHL_17['start_time'].dt.hour
PHL_17['weekday'] = PHL_17['start_time'].dt.weekday
PHL_17['month'] = PHL_17['start_time'].dt.month
PHL_17['duration'] = PHL_17['end_time'] - PHL_17['start_time']
# Could also define functions in order to map it to the dataframe

# %%
PHL_17[PHL_17["start_time"].dt.month == 12]
# Out:
#                 start_time            end_time  start_station_id  \
# 752942 2017-12-01 00:03:00 2017-12-01 00:22:00              3023
# 752943 2017-12-01 00:04:00 2017-12-01 00:08:00              3059
# 752944 2017-12-01 00:04:00 2017-12-01 00:08:00              3054
# 752945 2017-12-01 00:09:00 2017-12-01 00:29:00              3037
# 752946 2017-12-01 00:10:00 2017-12-01 00:17:00              3055
# ...                    ...                 ...               ...
# 788902 2017-12-31 23:05:00 2017-12-31 23:33:00              3070
# 788903 2017-12-31 23:11:00 2018-01-01 11:03:00              3107
# 788904 2017-12-31 23:18:00 2017-12-31 23:25:00              3033
# 788905 2017-12-31 23:39:00 2017-12-31 23:40:00              3163
# 788906 2017-12-31 23:41:00 2017-12-31 23:55:00              3163
#
#         end_station_id  bike_id user_type              start_station_name  \
# 752942            3035     5331  Indego30              Rittenhouse Square
# 752943            3013     2646  Indego30      Spring Garden Station, BSL
# 752944            3156    11775  Indego30                    Rodin Museum
# 752945            3053     5154  Indego30  Pennsylvania Convention Center
# 752946            3049    11933  Indego30                    8th & Market
# ...                ...      ...       ...                             ...
# 788902            3124     3708  Indego30      Spring Garden Station, MFL
# 788903            3165     5117  Indego30                33rd & Reservoir
# 788904            3046    11933  Indego30                 10th & Chestnut
# 788905            3163     6725  Indego30                   25th & Locust
# 788906            3057    11864  Indego30                   25th & Locust
#
#                   end_station_name        date  hour  weekday  month  \
# 752942             Dornsife Center  2017-12-01     0        4     12
# 752943             6th & Fairmount  2017-12-01     0        4     12
# 752944               20th & Market  2017-12-01     0        4     12
# 752945       Point Breeze & Tasker  2017-12-01     0        4     12
# 752946             Foglietta Plaza  2017-12-01     0        4     12
# ...                            ...         ...   ...      ...    ...
# 788902            Race Street Pier  2017-12-31    23        6     12
# 788903             24th & Race SRT  2017-12-31    23        6     12
# 788904                2nd & Market  2017-12-31    23        6     12
# 788905               25th & Locust  2017-12-31    23        6     12
# 788906  Philadelphia Museum of Art  2017-12-31    23        6     12
#
#               duration
# 752942 0 days 00:19:00
# 752943 0 days 00:04:00
# 752944 0 days 00:04:00
# 752945 0 days 00:20:00
# 752946 0 days 00:07:00
# ...                ...
# 788902 0 days 00:28:00
# 788903 0 days 11:52:00
# 788904 0 days 00:07:00
# 788905 0 days 00:01:00
# 788906 0 days 00:14:00
#
# [35965 rows x 13 columns]

# %% [markdown]
# Checking for further  **errorneous data**, *e.g. negative ride durations*

# %%
PHL_17["duration"].describe()
# Out:
# count                       788907
# mean     0 days 00:21:37.842863607
# std      0 days 01:14:50.111112609
# min              -1 days +23:28:00
# 25%                0 days 00:07:00
# 50%                0 days 00:11:00
# 75%                0 days 00:18:00
# max                6 days 04:09:00
# Name: duration, dtype: object

# %%
PHL_17[PHL_17["end_time"] < PHL_17["start_time"]]
# Out:
#                 start_time            end_time  start_station_id  \
# 704926 2017-11-05 01:35:00 2017-11-05 01:03:00              3118
# 704929 2017-11-05 01:39:00 2017-11-05 01:35:00              3066
# 704933 2017-11-05 01:51:00 2017-11-05 01:20:00              3157
#
#         end_station_id  bike_id user_type           start_station_name  \
# 704926            3111     6694  Indego30     46th Street Station, MFL
# 704929            3066     2551  Indego30               19th & Lombard
# 704933            3041    11750  Indego30  8th & Mifflin, Bok Building
#
#                          end_station_name        date  hour  weekday  month  \
# 704926  Parkside & Belmont, Case Building  2017-11-05     1        6     11
# 704929                     19th & Lombard  2017-11-05     1        6     11
# 704933                Girard Station, MFL  2017-11-05     1        6     11
#
#                 duration
# 704926 -1 days +23:28:00
# 704929 -1 days +23:56:00
# 704933 -1 days +23:29:00

# %% [markdown]
# Dropping the three rows with the negative durations

# %%
PHL_17.drop(PHL_17[PHL_17["end_time"] < PHL_17["start_time"]].index, inplace=True)

# %%
PHL_17[PHL_17["end_time"] < PHL_17["start_time"]]
# Out:
# Empty DataFrame
# Columns: [start_time, end_time, start_station_id, end_station_id, bike_id, user_type, start_station_name, end_station_name, date, hour, weekday, month, duration]
# Index: []

# %% [markdown]
# All rows with negative durations have been deleted successfully

# %%
PHL_17["duration"].describe()
# Out:
# count                       788904
# mean     0 days 00:21:37.852894648
# std      0 days 01:14:50.116447017
# min                0 days 00:01:00
# 25%                0 days 00:07:00
# 50%                0 days 00:11:00
# 75%                0 days 00:18:00
# max                6 days 04:09:00
# Name: duration, dtype: object

# %% [markdown]
# As seen above, the **average ride duration** is about **21 minutes**

# %% [markdown]
# Length of our current dataframe

# %%
len(PHL_17)
# Out:
# 788904

# %%
###ALLES BIS HIER KOPIEREN###

# %% [markdown]
# ## 1.2 Some first geographical visualizations

# %% [markdown]
# Let's do some first **geographical visualizations** on the Bike Dataset. Therefore we have to gain some more information on the stations by joining another **dataframe** to our existing bike dataframe:

# %% [markdown]
# We got **extended quaterly data** that we now want to **concatenate** in order to join some information to our existing table

# %%
PHL_extended_17_1 = pd.read_csv("PHL_extended_17_1.csv", encoding = "ISO-8859-1")
PHL_extended_17_2 = pd.read_csv("PHL_extended_17_2.csv", encoding = "ISO-8859-1")
PHL_extended_17_3 = pd.read_csv("PHL_extended_17_3.csv", encoding = "ISO-8859-1")
PHL_extended_17_4 = pd.read_csv("PHL_extended_17_4.csv", encoding = "ISO-8859-1")

frames = [PHL_extended_17_1,PHL_extended_17_2,PHL_extended_17_3,PHL_extended_17_4]
PHL_extended = pd.concat(frames)

PHL_extended.set_index("trip_id", inplace=True)

PHL_extended.head()
# Out:
#           duration     start_time       end_time  start_station_id  start_lat  \
# trip_id
# 87535955       660  1/1/2017 0:05  1/1/2017 0:16            3046.0  39.950119
# 87535954      2160  1/1/2017 0:21  1/1/2017 0:57            3110.0  39.961750
# 87535953      2100  1/1/2017 0:22  1/1/2017 0:57            3110.0  39.961750
# 87535952       720  1/1/2017 0:27  1/1/2017 0:39            3041.0  39.968491
# 87535951       480  1/1/2017 0:28  1/1/2017 0:36            3047.0  39.950710
#
#           start_lon  end_station_id    end_lat    end_lon  bike_id  \
# trip_id
# 87535955 -75.144722          3041.0  39.968491 -75.135460     5347
# 87535954 -75.136414          3054.0  39.962502 -75.174202     3364
# 87535953 -75.136414          3054.0  39.962502 -75.174202     2536
# 87535952 -75.135460          3005.0  39.947330 -75.144028     5176
# 87535951 -75.149208          3124.0  39.952950 -75.139793     5370
#
#           plan_duration trip_route_category passholder_type  start_station  \
# trip_id
# 87535955             30             One Way        Indego30            NaN
# 87535954              0             One Way         Walk-up            NaN
# 87535953              0             One Way         Walk-up            NaN
# 87535952             30             One Way        Indego30            NaN
# 87535951              0             One Way         Walk-up            NaN
#
#           end_station
# trip_id
# 87535955          NaN
# 87535954          NaN
# 87535953          NaN
# 87535952          NaN
# 87535951          NaN

# %% [markdown]
# Check if concatenation was successfull

# %%
print(len(PHL_extended_17_1))
print(len(PHL_extended_17_2))
print(len(PHL_extended_17_3))
print(len(PHL_extended_17_4))
print(len(PHL_extended))
# Out:
# 107772
# 220441
# 276785
# 183909
# 788907

# %%
PHL_extended.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 788907 entries, 87535955 to 223865569
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   duration             788907 non-null  int64
#  1   start_time           788907 non-null  object
#  2   end_time             788907 non-null  object
#  3   start_station_id     107772 non-null  float64
#  4   start_lat            788797 non-null  float64
#  5   start_lon            788797 non-null  float64
#  6   end_station_id       107772 non-null  float64
#  7   end_lat              782652 non-null  float64
#  8   end_lon              782652 non-null  float64
#  9   bike_id              788907 non-null  int64
#  10  plan_duration        788907 non-null  int64
#  11  trip_route_category  788907 non-null  object
#  12  passholder_type      788907 non-null  object
#  13  start_station        681135 non-null  float64
#  14  end_station          681135 non-null  float64
# dtypes: float64(8), int64(3), object(4)
# memory usage: 96.3+ MB

# %% [markdown]
# Dropping unessacary columns, only keep station id and location data

# %%
PHL_extended = PHL_extended[["start_station_id","end_station_id","start_lat", "start_lon", "end_lat","end_lon"]]

# %% [markdown]
# Checking if both station columns contain the same amount of stations

# %%
len(PHL_extended['start_station_id'].unique())
# Out:
# 107

# %%
len(PHL_extended['end_station_id'].unique())
# Out:
# 107

# %% [markdown]
# Now we can keep one of the station columns

# %%
PHL_extended.drop_duplicates(subset='start_station_id', inplace=True)
PHL_extended.drop('end_station_id', axis=1, inplace=True)
PHL_extended.drop('end_lat', axis=1, inplace=True)
PHL_extended.drop('end_lon', axis=1, inplace=True)
PHL_extended.head()
# Out:
#           start_station_id  start_lat  start_lon
# trip_id
# 87535955            3046.0  39.950119 -75.144722
# 87535954            3110.0  39.961750 -75.136414
# 87535952            3041.0  39.968491 -75.135460
# 87535951            3047.0  39.950710 -75.149208
# 87535949            3072.0  39.934448 -75.145409

# %%
PHL_extended['end_station_id'] = PHL_extended['start_station_id']
PHL_extended['end_lat'] = PHL_extended['start_lat']
PHL_extended['end_lon'] = PHL_extended['start_lon']
PHL_extended.head()
# Out:
#           start_station_id  start_lat  start_lon  end_station_id    end_lat  \
# trip_id
# 87535955            3046.0  39.950119 -75.144722          3046.0  39.950119
# 87535954            3110.0  39.961750 -75.136414          3110.0  39.961750
# 87535952            3041.0  39.968491 -75.135460          3041.0  39.968491
# 87535951            3047.0  39.950710 -75.149208          3047.0  39.950710
# 87535949            3072.0  39.934448 -75.145409          3072.0  39.934448
#
#             end_lon
# trip_id
# 87535955 -75.144722
# 87535954 -75.136414
# 87535952 -75.135460
# 87535951 -75.149208
# 87535949 -75.145409

# %% [markdown]
# Now we are trying to **merge our location data** to our existing bike dataframe by performing a **left join**

# %%
PHL_17 = pd.merge(PHL_17, PHL_extended[['start_station_id', 'start_lat', 'start_lon']],on='start_station_id', how='left')
PHL_17 = pd.merge(PHL_17, PHL_extended[['end_station_id', 'end_lat', 'end_lon']],on='end_station_id', how='left')

# %%
PHL_17
# Out:
#                 start_time            end_time  start_station_id  \
# 0      2017-01-01 00:05:00 2017-01-01 00:16:00              3046
# 1      2017-01-01 00:21:00 2017-01-01 00:57:00              3110
# 3       (39.9685, -75.1355)   (39.9473, -75.144)
# 4       (39.9507, -75.1492)   (39.953, -75.1398)
# ...                     ...                  ...
# 788899  (39.9507, -75.1492)  (39.9637, -75.1816)
# 788900  (39.9918, -75.1864)  (39.9456, -75.1735)
# 788901  (39.9507, -75.1492)  (39.9637, -75.1816)
# 788902  (39.9522, -75.2031)  (39.9522, -75.2031)
# 788903  (39.9625, -75.1742)  (39.9535, -75.1719)
#
# [788904 rows x 19 columns]

# %%
PHL_17[PHL_17.isnull().any(axis=1)]
# Out:
#                 start_time            end_time  start_station_id  \
# 76     2017-01-01 11:30:00 2017-01-02 14:21:00              3068
# 164    2017-01-01 12:53:00 2017-01-01 13:53:00              3047
# 223    2017-01-01 13:38:00 2017-01-01 13:47:00              3051
# 252    2017-01-01 14:00:00 2017-01-01 17:02:00              3010
# 281    2017-01-01 14:26:00 2017-01-02 14:19:00              3047
# ...                    ...                 ...               ...
# 788590 2017-03-09 08:08:00 2017-03-09 11:10:00              3028
# 788659 2017-03-09 08:27:00 2017-03-09 13:02:00              3028
# 788681 2017-03-09 08:33:00 2017-03-09 08:39:00              3107
# 788787 2017-03-09 09:09:00 2017-03-09 09:27:00              3055
# 788864 2017-03-09 09:42:00 2017-03-09 13:13:00              3086
#
#         end_station_id  bike_id user_type      start_station_name  \
# 76                3000     3553  Indego30         Broad & Federal
# 164               3000     5369   Walk-up  Independence Mall, NPS
# 223               3000     5215  Indego30        23rd & Fairmount
# 252               3000     3331   Walk-up           15th & Spruce
# 281               3000     5240   Walk-up  Independence Mall, NPS
# ...                ...      ...       ...                     ...
# 788590            3000     5131  Indego30        4th & Bainbridge
# 788659            3000     2504  Indego30        4th & Bainbridge
# 788681            3000     2584  Indego30        33rd & Reservoir
# 788787            3000    11004  Indego30            8th & Market
# 788864            3000     2508  Indego30       Broad & Christian
#
#        end_station_name        date  hour  weekday  month        duration  \
# 76      Virtual Station  2017-01-01    11        6      1 1 days 02:51:00
# 164     Virtual Station  2017-01-01    12        6      1 0 days 01:00:00
# 223     Virtual Station  2017-01-01    13        6      1 0 days 00:09:00
# 252     Virtual Station  2017-01-01    14        6      1 0 days 03:02:00
# 281     Virtual Station  2017-01-01    14        6      1 0 days 23:53:00
# ...                 ...         ...   ...      ...    ...             ...
# 788590  Virtual Station  2017-03-09     8        3      3 0 days 03:02:00
# 788659  Virtual Station  2017-03-09     8        3      3 0 days 04:35:00
# 788681  Virtual Station  2017-03-09     8        3      3 0 days 00:06:00
# 788787  Virtual Station  2017-03-09     9        3      3 0 days 00:18:00
# 788864  Virtual Station  2017-03-09     9        3      3 0 days 03:31:00
#
#         start_lat  start_lon  end_lat  end_lon    start_coordinates  \
# 76      39.935490 -75.167107      NaN      NaN  (39.9355, -75.1671)
# 164     39.950710 -75.149208      NaN      NaN  (39.9507, -75.1492)
# 223     39.967442 -75.175072      NaN      NaN  (39.9674, -75.1751)
# 252     39.947109 -75.166183      NaN      NaN  (39.9471, -75.1662)
# 281     39.950710 -75.149208      NaN      NaN  (39.9507, -75.1492)
# ...           ...        ...      ...      ...                  ...
# 788590  39.940609 -75.149582      NaN      NaN  (39.9406, -75.1496)
# 788659  39.940609 -75.149582      NaN      NaN  (39.9406, -75.1496)
# 788681  39.982029 -75.188660      NaN      NaN   (39.982, -75.1887)
# 788787  39.951118 -75.154572      NaN      NaN  (39.9511, -75.1546)
# 788864  39.940189 -75.166908      NaN      NaN  (39.9402, -75.1669)
#
#        end_coordinates
# 76          (nan, nan)
# 164         (nan, nan)
# 223         (nan, nan)
# 252         (nan, nan)
# 281         (nan, nan)
# ...                ...
# 788590      (nan, nan)
# 788659      (nan, nan)
# 788681      (nan, nan)
# 788787      (nan, nan)
# 788864      (nan, nan)
#
# [88449 rows x 19 columns]

# %% [markdown]
# Stations with id 3000 are virtual stations

# %%
len(PHL_17[PHL_17["start_station_id"] == 3000])
# Out:
# 110

# %%
len(PHL_17[PHL_17["end_station_id"] == 3000])
# Out:
# 6255

# %% [markdown]
# We drop the stations with id 3000 (virtual stations). Otherwise folium will throw an error!

# %%
PHL_17_geo = PHL_17.copy()

PHL_17_geo.drop(PHL_17_geo[PHL_17_geo["start_station_id"] == 3000].index, inplace=True)
PHL_17_geo.drop(PHL_17_geo[PHL_17_geo["end_station_id"] == 3000].index, inplace=True)

# %%
PHL_17_geo.head()
# Out:
#            start_time            end_time  start_station_id  end_station_id  \
# 0 2017-01-01 00:05:00 2017-01-01 00:16:00              3046            3041
# 1 2017-01-01 00:21:00 2017-01-01 00:57:00              3110            3054
# 2 2017-01-01 00:22:00 2017-01-01 00:57:00              3110            3054
# 3 2017-01-01 00:27:00 2017-01-01 00:39:00              3041            3005
# 4 2017-01-01 00:28:00 2017-01-01 00:36:00              3047            3124
#
#    bike_id user_type           start_station_name     end_station_name  \
# 0     5347  Indego30                 2nd & Market  Girard Station, MFL
# 1     3364   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 2     2536   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 3     5176  Indego30          Girard Station, MFL    Welcome Park, NPS
# 4     5370   Walk-up       Independence Mall, NPS     Race Street Pier
#
#          date  hour  weekday  month        duration  start_lat  start_lon  \
# 0  2017-01-01     0        6      1 0 days 00:11:00  39.950119 -75.144722
# 1  2017-01-01     0        6      1 0 days 00:36:00  39.961750 -75.136414
# 2  2017-01-01     0        6      1 0 days 00:35:00  39.961750 -75.136414
# 3  2017-01-01     0        6      1 0 days 00:12:00  39.968491 -75.135460
# 4  2017-01-01     0        6      1 0 days 00:08:00  39.950710 -75.149208
#
#      end_lat    end_lon    start_coordinates      end_coordinates
# 0  39.968491 -75.135460  (39.9501, -75.1447)  (39.9685, -75.1355)
# 1  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 2  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 3  39.947330 -75.144028  (39.9685, -75.1355)   (39.9473, -75.144)
# 4  39.952950 -75.139793  (39.9507, -75.1492)   (39.953, -75.1398)

# %% [markdown]
# Double checking if main dataframe was accidentially edited

# %%
len(PHL_17[PHL_17["start_station_id"] == 3000])
# Out:
# 110

# %%
len(PHL_17[PHL_17["end_station_id"] == 3000])
# Out:
# 6255

# %%
len(PHL_17_geo[PHL_17_geo["start_station_id"] == 3000])
# Out:
# 0

# %%
PHL_17_geo.dropna(axis=0, inplace=True)

# %%
len(PHL_17_geo)
# Out:
# 700455

# %% [markdown]
# Length is now 700455 rows instead of 788904 as after previous dropping

# %% [markdown]
# Now we can pick **one bike** and visualize its movement on a heatmap

# %%
bike_list_unique = PHL_17_geo["bike_id"].unique()
bike_selected = random.choice(bike_list_unique)
print(bike_selected)
# Out:
# 3484

# %% [markdown]
# Defining a subset of the dataframe that only contains unique stations and its coordinates

# %%
stations = PHL_17_geo[["start_station_id", "start_coordinates"]]
stations["count"] = stations.groupby("start_station_id").start_station_id.transform('count')
stations = stations.drop_duplicates(subset = ["start_station_id"])
stations.head(10)
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/88315326.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations["count"] = stations.groupby("start_station_id").start_station_id.transform('count')
#     start_station_id    start_coordinates  count
# 0               3046  (39.9501, -75.1447)   9010
# 1               3110  (39.9618, -75.1364)   3319
# 3               3041  (39.9685, -75.1355)   3984
# 4               3047  (39.9507, -75.1492)   8627
# 6               3072  (39.9344, -75.1454)   4530
# 7               3033    (39.95, -75.1567)   8093
# 8               3013  (39.9632, -75.1479)   4754
# 9               3124   (39.953, -75.1398)   4967
# 12              3066  (39.9456, -75.1735)  10106
# 14              3014  (39.9589, -75.1737)   1871

# %%
len(PHL_17_geo[PHL_17_geo["start_station_id"] == 3046])
# Out:
# 9010

# %%
stations.describe()
# Out:
#        start_station_id         count
# count        105.000000    105.000000
# mean        3062.428571   6671.000000
# std           37.311026   4731.086469
# min         3004.000000    720.000000
# 25%         3030.000000   3103.000000
# 50%         3059.000000   5753.000000
# 75%         3099.000000   9087.000000
# max         3129.000000  23221.000000

# %%
## Try to visualize the popularity (count) of each station by hue

# %% [markdown]
# Defining a map that visualizes the **starting points** of a bike

# %%
#define new map

PHL_17_heat_map = folium.Map(location=(39.952583, -75.165222),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

# add heat map

PHL_17_heat_map.add_child(plugins.HeatMap(PHL_17_geo[PHL_17_geo["bike_id"]==bike_selected]["start_coordinates"], radius=20))

# add stations

#stations = list(PHL_17["start_coordinates"].unique())

for indice,row in stations.iterrows():
    folium.CircleMarker(radius=5, location=row["start_coordinates"], popup=row['start_station_id'], 
                                 color='crimson', fill_color='crimson').add_to(PHL_17_heat_map)

PHL_17_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c927d6975c69191e6cd933a9a457162 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c927d6975c69191e6cd933a9a457162&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3c927d6975c69191e6cd933a9a457162 = L.map(
#                 &quot;map_3c927d6975c69191e6cd933a9a457162&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map
# 1531                           University City Station  2017-01-10     6
# ...                                                ...         ...   ...
# 788899                      Philadelphia Museum of Art  2017-03-09     9
# 788900                                  19th & Lombard  2017-03-09     9
# 788901                      Philadelphia Museum of Art  2017-03-09     9
# 788902                                   40th & Spruce  2017-03-09     9
# 788903                                   19th & Market  2017-03-09     9
#
#         weekday  month        duration  start_lat  start_lon    end_lat  \
# 1527          1      1 0 days 02:28:00  39.955109 -75.209869  39.953800
# 1528          1      1 0 days 00:10:00  39.941380 -75.145638  39.934010
# 1529          1      1 0 days 00:13:00  39.943909 -75.167351  39.959229
# 1530          1      1 0 days 00:11:00  39.971210 -75.159698  39.953548
# 1531          1      1 0 days 00:11:00  39.945171 -75.159927  39.948872
# ...         ...    ...             ...        ...        ...        ...
# 788899        3      3 0 days 00:57:00  39.950710 -75.149208  39.963711
# 788900        3      3 0 days 00:37:00  39.991791 -75.186371  39.945610
# 788901        3      3 0 days 00:56:00  39.950710 -75.149208  39.963711
# 788902        3      3 0 days 07:01:00  39.952202 -75.203110  39.952202
# 788903        3      3 0 days 00:07:00  39.962502 -75.174202  39.953548
#
#           end_lon    start_coordinates      end_coordinates
# 1527   -75.194794  (39.9551, -75.2099)  (39.9538, -75.1948)
# 1528   -75.150940  (39.9414, -75.1456)   (39.934, -75.1509)
# 1529   -75.170357  (39.9439, -75.1674)  (39.9592, -75.1704)
# 1530   -75.171921  (39.9712, -75.1597)  (39.9535, -75.1719)
# 1531   -75.189857  (39.9452, -75.1599)  (39.9489, -75.1899)
# ...           ...                  ...                  ...
# 788899 -75.181602  (39.9507, -75.1492)  (39.9637, -75.1816)
# 788900 -75.173477  (39.9918, -75.1864)  (39.9456, -75.1735)
# 788901 -75.181602  (39.9507, -75.1492)  (39.9637, -75.1816)
# 788902 -75.203110  (39.9522, -75.2031)  (39.9522, -75.2031)
# 788903 -75.171921  (39.9625, -75.1742)  (39.9535, -75.1719)
#
# [131018 rows x 19 columns]

# %%
#define new map

PHL_17_heat_map = folium.Map(location=(39.952583, -75.165222),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

# add heat map

PHL_17_heat_map.add_child(plugins.HeatMap(PHL_17_geo[PHL_17_geo["bike_id"]==bike_selected]["end_coordinates"][(PHL_17_geo["hour"] >= 6) & (PHL_17_geo["hour"] <=9) & (PHL_17_geo["weekday"] <= 4)], radius=20))

# add stations

#stations = list(PHL_17_geo["end_coordinates"].unique())

for indice,row in stations.iterrows():
    folium.CircleMarker(radius=5, location=row["start_coordinates"], popup=row['start_station_id'], 
                                 color='crimson', fill_color='crimson').add_to(PHL_17_heat_map)

PHL_17_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ecf1e40d43d328af4c9ea604c7cca0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ecf1e40d43d328af4c9ea604c7cca0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ecf1e40d43d328af4c9ea604c7cca0a = L.map(
#                 &quot;map_2ecf1e40d43d328af4c9ea604c7cca0a&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map

#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2ecf1e40d43d328af4c9ea604c7cca0a);
#
#
#         var popup_4fb8767f141e96246516fc289bc0696f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var

# %% [markdown]
# It seems as if the trips are mostly heading towards the **city center** in the morning hours

# %% [markdown]
# Visualizing where people are traveling to in the **evening hours** (3-6pm) on **workdays**

# %%
PHL_17_geo[(PHL_17_geo["hour"] >= 15) & (PHL_17_geo["hour"] <=18) & (PHL_17_geo["weekday"] <= 4)]
# Out:
#                 start_time            end_time  start_station_id  \
# 1036   2017-01-10 15:02:00 2017-01-10 16:24:00              3035
# 1037   2017-01-10 15:02:00 2017-01-10 15:12:00              3062
# 1038   2017-01-10 15:04:00 2017-01-10 15:10:00              3038
# 1039   2017-01-10 15:04:00 2017-01-10 15:15:00              3025
# 1040   2017-01-10 15:04:00 2017-01-10 15:13:00              3029
# ...                    ...                 ...               ...
# 787929 2017-03-09 18:58:00 2017-03-09 19:09:00              3032
# 787930 2017-03-09 18:58:00 2017-03-09 19:11:00              3029
# 787931 2017-03-09 18:59:00 2017-03-09 19:09:00              3023
# 787932 2017-03-09 18:59:00 2017-03-09 19:11:00              3061
# 787933 2017-03-09 18:59:00 2017-03-09 19:15:00              3004
#
#         end_station_id  bike_id user_type  \
# 1036              3029     2728   Walk-up
# 1037              3086     5287  Indego30
# 1038              3022     5332  Indego30
# 1039              3032     3300  Indego30
# 1040              3112     2541  Indego30
# ...                ...      ...       ...
# 787929            3007     2539  Indego30
# 787930            3063     2604  Indego30
# 787931            3101     5351  Indego30
# 787932            3051     3405  Indego30
# 787933            3013    11008  Indego30
#
#                                     start_station_name  \
# 1036                                   Dornsife Center
# 1037                                     24th & Sansom
# 1038    The Children's Hospital of Philadelphia (CHOP)
# 1039                                 11th & Washington
# 1040                                     36th & Sansom
# ...                                                ...
# 787929                                    23rd & South
# 787930                                   36th & Sansom
# 787931                              Rittenhouse Square
# 787932                                   23rd & Market
# 787933               Municipal Services Building Plaza
#
#                   end_station_name        date  hour  weekday  month  \
# 1036                 36th & Sansom  2017-01-10    15        1      1
# 1037             Broad & Christian  2017-01-10    15        1      1
# 1038    Amtrak 30th Street Station  2017-01-10    15        1      1
# 1039                  23rd & South  2017-01-10    15        1      1
# 1040                 48th & Spruce  2017-01-10    15        1      1
# ...                            ...         ...   ...      ...    ...
# 787929      11th & Pine, Kahn Park  2017-03-09    18        3      3
# 787930                 17th & Pine  2017-03-09    18        3      3
# 787931                11th & South  2017-03-09    18        3      3
# 787932            23rd & Fairmount  2017-03-09    18        3      3
# 787933             6th & Fairmount  2017-03-09    18        3      3
#
#               duration  start_lat  start_lon    end_lat    end_lon  \
# 1036   0 days 01:22:00  39.962711 -75.194191  39.953800 -75.194794
# 1037   0 days 00:10:00  39.951969 -75.179428  39.940189 -75.166908
# 1038   0 days 00:06:00  39.947811 -75.194092  39.954720 -75.183228
# 1039   0 days 00:11:00  39.937241 -75.161201  39.945271 -75.179710
# 1040   0 days 00:09:00  39.953800 -75.194794  39.953732 -75.218246
# ...                ...        ...        ...        ...        ...
# 787929 0 days 00:11:00  39.945271 -75.179710  39.945171 -75.159927
# 787930 0 days 00:13:00  39.953800 -75.194794  39.946331 -75.169800
# 787931 0 days 00:10:00  39.950481 -75.172859  39.942951 -75.159554
# 787932 0 days 00:12:00  39.954250 -75.177612  39.967442 -75.175072
# 787933 0 days 00:16:00  39.953781 -75.163742  39.963169 -75.147919
#
#           start_coordinates      end_coordinates
# 1036    (39.9627, -75.1942)  (39.9538, -75.1948)
# 1037     (39.952, -75.1794)  (39.9402, -75.1669)
# 1038    (39.9478, -75.1941)  (39.9547, -75.1832)
# 1039    (39.9372, -75.1612)  (39.9453, -75.1797)
# 1040    (39.9538, -75.1948)  (39.9537, -75.2182)
# ...                     ...                  ...
# 787929  (39.9453, -75.1797)  (39.9452, -75.1599)
# 787930  (39.9538, -75.1948)  (39.9463, -75.1698)
# 787931  (39.9505, -75.1729)   (39.943, -75.1596)
# 787932  (39.9542, -75.1776)  (39.9674, -75.1751)
# 787933  (39.9538, -75.1637)  (39.9632, -75.1479)
#
# [182819 rows x 19 columns]

# %%
#define new map

PHL_17_heat_map = folium.Map(location=(39.952583, -75.165222),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

# add heat map

PHL_17_heat_map.add_child(plugins.HeatMap(PHL_17_geo[PHL_17_geo["bike_id"]==bike_selected]["end_coordinates"][(PHL_17_geo["hour"] >= 15) & (PHL_17_geo["hour"] <=18) & (PHL_17_geo["weekday"] <= 4)], radius=20))

# add stations

#stations = list(PHL_17["end_coordinates"].unique())

for indice,row in stations.iterrows():
    folium.CircleMarker(radius=5, location=row["start_coordinates"], popup=row['start_station_id'], 
                                 color='crimson', fill_color='crimson').add_to(PHL_17_heat_map)

PHL_17_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26057e2089255184dd132d3fcde0f4fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26057e2089255184dd132d3fcde0f4fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_26057e2089255184dd132d3fcde0f4fd = L.map(
#                 &quot;map_26057e2089255184dd132d3fcde0f4fd&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_26057e2089255184dd132d3fcde0f4fd);
#
#
#
#
#
#             var tile_layer_2d2edabdb2a189d8761c6720dbda3b99 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_26057e2089255184dd132d3fcde0f4fd);
#
#
#             var heat_map_319879123167973f2e185ca324f01358 = L.heatLayer(
#                 [[39.9473, -75.157], [39.9414, -75.1456], [39.9463, -75.1698], [39.9406, -75.1496], [39.9406, -75.1496], [39.934, -75.1509], [39.9614, -75.1524], [39.9479, -75.1624], [39.9453, -75.1797], [39.9343, -75.1604], [39.9721, -75.1635], [39.9752, -75.1867], [39.9637, -75.1816], [39.9538, -75.1948], [39.9547, -75.1832], [39.9479, -75.1624], [39.9414, -75.1456], [39.9355, -75.1671], [39.9378, -75.1801], [39.9542, -75.1776], [39.9558, -75.1898], [39.9698, -75.1418], [39.9451, -75.1425], [39.9542, -75.1776], [39.9571, -75.2018], [39.9626, -75.1617], [39.9547, -75.1832], [39.9308, -75.1747], [39.9355, -75.1671
&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3046&lt;/div&gt;`)[0];
#             popup_cd0e4447e3bef48c076e1789e8ba70e5.setContent(html_a639af0c09fa3a89e48934f24d7d4d2b);

# %% [markdown]
# The situation in the evening hours is more diffuse. Here the trips are heading **more towards the outskirts**

# %% [markdown]
# In contray, let's visualize where people are renting their bikes from **on weekends** (start stations)

# %%
#define new map

PHL_17_heat_map = folium.Map(location=(39.952583, -75.165222),tiles='OpenStreetMap',zoom_start=12, control_scale=True, max_zoom=20)

# add heat map

PHL_17_heat_map.add_child(plugins.HeatMap(PHL_17_geo[PHL_17_geo["bike_id"]==bike_selected]["start_coordinates"][(PHL_17_geo["weekday"] >= 5) & (PHL_17_geo["weekday"] <= 6)], radius=20))

# add stations

#stations = list(PHL_17["start_coordinates"].unique())

for indice,row in stations.iterrows():
    folium.CircleMarker(radius=5, location=row["start_coordinates"], popup=row['start_station_id'], 
                                 color='crimson', fill_color='crimson').add_to(PHL_17_heat_map)

PHL_17_heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbaf128b683c73e2de196d250bbe730f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbaf128b683c73e2de196d250bbe730f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fbaf128b683c73e2de196d250bbe730f = L.map(
#                 &quot;map_fbaf128b683c73e2de196d250bbe730f&quot;,
#                 {
#                     center: [39.952583, -75.165222],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fbaf128b683c73e2de196d250bbe730f);
#
#
#
#
#
#             var tile_layer_16ea2fa6dd5539ac5193a9c7c1ff5f01 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fbaf128b683c73e2de196d250bbe730f);
#
#
#             var heat_map_b7d1be8855d5aaf257ea0dfb70a34138 = L.heatLayer(
#                 [[39.98, -75.1552], [39.9727, -75.1794], [39.98, -75.1709], [39.934, -75.1509], [39.934, -75.1509], [39.9439, -75.1674], [39.9414, -75.1456], [39.9384, -75.1733], [39.9538, -75.1948], [39.9542, -75.1614], [39.9501, -75.1447], [39.9451, -75.1425], [39.9637, -75.1816], [39.9558, -75.1898], [39.9542, -75.1776], [39.9505, -75.1729], [39.9535, -75.1719], [39.9617, -75.1879], [39.9558, -75.1898], [39.9558, -75.1898], [39.953, -75.1398], [39.953, -75.1398], [39.9637, -75.1816], [39.9547, -75.1832], [39.9547, -75.1832], [39.9505, -75.1729], [39.9592, -75.1704], [39.9479, -75.1624], [39.943, -75.1596], [39.953, -75.1398], [39.9505, -75.1729], [39.9384, -75.1733], [39.943, -75.1596], [39.9456, -75.1735], [39.9384, -75.1733], [39.9463, -75.1698], [39.9479, -75.1624], [39.9453, -75.1797], [39.9627, -75.1942], [39.9453, -75.1797], [39.9637, -75.1816], [39.9507, -75.1492], [39.9542, -75.1614], [39.9637, -75.1816], [39.9527, -75.1598], [39.9767, -75.1581], [39.9511, -75.1546], [39.9539, -75.169], [39.9439, -75.1674], [39.9527, -75.1598], [39.9685, -75.1355], [39.9614, -75.1524], [39.9479, -75.1624], [39.9402, -75.1669], [39.9355, -75.1671], [39.9505, -75.1729], [39.9471, -75.1662], [39.934, -75.1509], [39.9456, -75.1735], [39.9453, -75.1797], [39.9551, -75.2099], [39.9378, -75.1801], [39.9422, -75.1775], [39.9672, -75.1612], [39.9682, -75.1803], [39.9784, -75.224], [39.9355, -75.1671], [39.9355, -75.1671], [39.9471, -75.1662], [39.952, -75.1794], [39.9471, -75.1662], [39.9422, -75.1775], [39.9422, -75.1775], [39.9422, -75.1775], [39.9422, -75.1775], [39.9505, -75.1729], [39.937, -75.1504], [39.943, -75.1596], [39.943, -75.1596], [39.9625, -75.1742], [39.9474, -75.1489], [39.9414, -75.1456], [39.9332, -75.1625], [39.9674, -75.1751], [39.9625, -75.1742], [39.9625, -75.1742], [39.9532, -75.1655], [39.9332, -75.1625], [39.9479, -75.1624], [39.9332, -75.1625], [39.9571, -75.2018], [39.9332, -75.1625], [39.9532, -75.1655], [39.9637, -75.1816], [39.9478, -75.1941], [39.9547, -75.1832]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 20}
#             ).addTo(map_fbaf128b683c73e2de196d250bbe730f);
#
#
#             var circle_marker_26673a654e67f4447ff27ad2eba5de1c = L.circleMarker(
#                 [39.9501, -75.1447],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fbaf128b683c73e2de196d250bbe730f);
#
#
#         var popup_280b6b1b111ec2c6056c91d5fc6c6297 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3c6bcaf25a318731db8a9c4869c6b50b = $(`&lt;div id=&quot;html_3c6bcaf25a318731db8a9c4869c6b50b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3046&lt;/div&gt;`)[0];
#             popup_280b6b1b111ec2c6056c91d5fc6c6297.setContent(html_3c6bcaf25a318731db8a9c4869c6b50b);
#
#
#         circle_marker_26673a654e67f4447ff27ad2eba5de1c.bindPopup(popup_280b6b1b111ec2c6056c91d5fc6c6297)
#         ;
#
#
#
#
#             var circle_marker_eab004cb1d05596d5236545229af9082 = L.circleMarker(
#                 [39.9618, -75.1364],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;,

# %% [markdown]
# In order to make the previous visualization more precious, let's integrate some POI data found on the following website  https://www.opendataphilly.org/dataset/city-landmarks

# %%
PHL_POI = pd.read_csv("PHL_POI.csv", encoding = "ISO-8859-1")

# %%
PHL_POI.head()
# Out:
#    ï»¿OBJECTID                                       NAME  \
# 0            1                 Chestnut Hill East Station
# 1            2                   India Pentecostal Church
# 2            3  Little Flower Catholic School High School
# 3            4                       Sandmeyer Lane Plaza
# 4            5                          Trocadero Theatre
#
#                     ADDRESS               FEAT_TYPE     SUB_TYPE VANITY_NAME  \
# 0  100 E. Chestnut Hill Ave          Transportation          NaN         NaN
# 1            1001 HOWELL ST        House of Worship          NaN         NaN
# 2         1001 W LUZERNE ST                  School  High School         NaN
# 3        10006 SANDMEYER LN  Shopping Center Ground          NaN         NaN
# 4           1003-05 ARCH ST                 Theatre          NaN         NaN
#
#   SECONDARY_NAME BLDG           PARENT_NAME             PARENT_TYPE   ACREAGE  \
# 0            NaN    Y                   NaN                     NaN  0.206112
# 1            NaN    Y                   NaN                     NaN  0.045186
# 2            NaN    Y                   NaN                     NaN  1.289753
# 3            NaN    Y  Sandmeyer Lane Plaza  Shopping Center Ground  0.251364
# 4            NaN    Y                   NaN                     NaN  0.208510
#
#    PARENT_ACREAGE   Shape__Area  Shape__Length
# 0     2839.623722   8978.187683     913.041444
# 1     2839.623722   1968.290283     193.948756
# 2     2839.623722  56181.436035    1754.992341
# 3        0.745275  10949.362183     526.073709
# 4     2839.623722   9082.677856     456.824201

# %% [markdown]
# *************************

# %%
#from geopy.geocoders import GoogleV3
#geolocator = GoogleV3()
#location = geolocator.geocode("175 5th Avenue NYC")
#print(location.address)

# %% [markdown]
# ## 1.3 Weather Dataset

# %% [markdown]
# Reading in the **weather dataset** and performing some basic operations

# %%
PHL_weather = pd.read_csv("PHL_weather_hourly.csv", encoding = "ISO-8859-1")

# %%
PHL_weather.head()
# Out:
#              date_time  max_temp  min_temp  precip
# 0  2015-01-02 01:00:00       3.3       3.3     0.0
# 1  2015-01-02 02:00:00       2.8       2.8     0.0
# 2  2015-01-02 03:00:00       2.2       2.2     0.0
# 3  2015-01-02 04:00:00       0.6       0.6     0.0
# 4  2015-01-02 05:00:00       1.1       1.1     0.0

# %% [markdown]
# Changing datatype from string to **datetime** in order to make the dataframe **maskable**

# %%
PHL_weather["date_time"] = pd.to_datetime(PHL_weather["date_time"])
PHL_weather.set_index("date_time", inplace = True)

# %%
PHL_weather
# Out:
#                      max_temp  min_temp  precip
# date_time
# 2015-01-02 01:00:00       3.3       3.3     0.0
# 2015-01-02 02:00:00       2.8       2.8     0.0
# 2015-01-02 03:00:00       2.2       2.2     0.0
# 2015-01-02 04:00:00       0.6       0.6     0.0
# 2015-01-02 05:00:00       1.1       1.1     0.0
# ...                       ...       ...     ...
# 2020-01-01 20:00:00       5.6       5.6     0.0
# 2020-01-01 21:00:00       5.6       5.6     0.0
# 2020-01-01 22:00:00       3.3       3.3     0.0
# 2020-01-01 23:00:00       2.2       2.2     0.0
# 2020-01-02 00:00:00       1.7       1.7     0.0
#
# [43848 rows x 3 columns]

# %% [markdown]
# The dataframe holds data from 2015 to 2020. Since we only want data on year 2017, we need to **mask the dataframe**

# %%
PHL_weather_17 = PHL_weather[PHL_weather.index.year == 2017]
PHL_weather_17
# Out:
#                      max_temp  min_temp  precip
# date_time
# 2017-01-01 01:00:00       6.1       6.1     0.0
# 2017-01-01 02:00:00       6.7       6.7     0.0
# 2017-01-01 03:00:00       7.2       7.2     0.0
# 2017-01-01 04:00:00       7.8       7.8     0.0
# 2017-01-01 05:00:00       7.8       7.8     0.0
# ...                       ...       ...     ...
# 2017-12-31 19:00:00      -8.9      -8.9     0.0
# 2017-12-31 20:00:00      -8.9      -8.9     0.0
# 2017-12-31 21:00:00      -9.4      -9.4     0.0
# 2017-12-31 22:00:00     -10.0     -10.0     0.0
# 2017-12-31 23:00:00     -10.0     -10.0     0.0
#
# [8755 rows x 3 columns]

# %% [markdown]
# Now that we have a dedicated dataframe for 2017, let's do some basic operations

# %%
PHL_weather_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8755 entries, 2017-01-01 01:00:00 to 2017-12-31 23:00:00
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   max_temp  8755 non-null   float64
#  1   min_temp  8755 non-null   float64
#  2   precip    8755 non-null   float64
# dtypes: float64(3)
# memory usage: 273.6 KB

# %%
PHL_weather_17.describe()
# Out:
#           max_temp     min_temp       precip
# count  8755.000000  8755.000000  8755.000000
# mean     14.434792    14.360423     0.078355
# std       9.802007     9.787853     0.268745
# min     -11.100000   -11.100000     0.000000
# 25%       6.700000     6.700000     0.000000
# 50%      15.000000    15.000000     0.000000
# 75%      22.200000    22.200000     0.000000
# max      35.000000    35.000000     1.000000

# %% [markdown]
# Now let's check for any NULL values and inconsistencies

# %%
PHL_weather_17[PHL_weather_17.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [max_temp, min_temp, precip]
# Index: []

# %%
print(PHL_weather_17.isnull().sum())
# Out:
# max_temp    0
# min_temp    0
# precip      0
# dtype: int64

# %% [markdown]
# Computing the average temperature in a new column

# %%
PHL_weather_17["avg_tmp"] = (PHL_weather_17["min_temp"]+PHL_weather_17["max_temp"])/2
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/2651450751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PHL_weather_17["avg_tmp"] = (PHL_weather_17["min_temp"]+PHL_weather_17["max_temp"])/2

# %%
PHL_weather_17.head()
# Out:
#                      max_temp  min_temp  precip  avg_tmp
# date_time
# 2017-01-01 01:00:00       6.1       6.1     0.0      6.1
# 2017-01-01 02:00:00       6.7       6.7     0.0      6.7
# 2017-01-01 03:00:00       7.2       7.2     0.0      7.2
# 2017-01-01 04:00:00       7.8       7.8     0.0      7.8
# 2017-01-01 05:00:00       7.8       7.8     0.0      7.8

# %% [markdown]
# ## 1.4 Some more trip-level feature engineering

# %%
from math import radians, cos, sin, asin, sqrt

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # Radius of earth in kilometers. Use 3956 for miles. Determines return value units.
    return c * r

# %%
PHL_17["haversine_km"] = PHL_17.apply(lambda x: haversine(x["start_lon"], x["start_lat"], x["end_lon"], x["end_lat"]), axis=1)

# %%
PHL_17.head()
# Out:
#            start_time            end_time  start_station_id  end_station_id  \
# 0 2017-01-01 00:05:00 2017-01-01 00:16:00              3046            3041
# 1 2017-01-01 00:21:00 2017-01-01 00:57:00              3110            3054
# 2 2017-01-01 00:22:00 2017-01-01 00:57:00              3110            3054
# 3 2017-01-01 00:27:00 2017-01-01 00:39:00              3041            3005
# 4 2017-01-01 00:28:00 2017-01-01 00:36:00              3047            3124
#
#    bike_id user_type           start_station_name     end_station_name  \
# 0     5347  Indego30                 2nd & Market  Girard Station, MFL
# 1     3364   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 2     2536   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 3     5176  Indego30          Girard Station, MFL    Welcome Park, NPS
# 4     5370   Walk-up       Independence Mall, NPS     Race Street Pier
#
#          date  hour  weekday  month        duration  start_lat  start_lon  \
# 0  2017-01-01     0        6      1 0 days 00:11:00  39.950119 -75.144722
# 1  2017-01-01     0        6      1 0 days 00:36:00  39.961750 -75.136414
# 2  2017-01-01     0        6      1 0 days 00:35:00  39.961750 -75.136414
# 3  2017-01-01     0        6      1 0 days 00:12:00  39.968491 -75.135460
# 4  2017-01-01     0        6      1 0 days 00:08:00  39.950710 -75.149208
#
#      end_lat    end_lon    start_coordinates      end_coordinates  \
# 0  39.968491 -75.135460  (39.9501, -75.1447)  (39.9685, -75.1355)
# 1  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 2  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 3  39.947330 -75.144028  (39.9685, -75.1355)   (39.9473, -75.144)
# 4  39.952950 -75.139793  (39.9507, -75.1492)   (39.953, -75.1398)
#
#    haversine_km
# 0      2.190091
# 1      3.221661
# 2      3.221661
# 3      2.463715
# 4      0.840301

# %%
PHL_17["haversine_km"].describe()
# Out:
# count    700455.000000
# mean          1.652805
# std           1.035866
# min           0.000000
# 25%           0.956096
# 50%           1.520589
# 75%           2.209403
# max           8.291972
# Name: haversine_km, dtype: float64

# %%
PHL_17['net_speed'] = PHL_17['haversine_km'] / (PHL_17['duration'].dt.total_seconds() / 3600)

# %% [markdown]
# ## 1.5 Finding patterns within the data

# %% [markdown]
# Probably the most important clusters/clusters are found within the **user types**. Some user types may be travelling at a higher **speed**, a longer **distance** or for a longer **time**. That is what we are trying to figure out in the following.

# %%
# hourly demand by usertype
bike_hourly_demand_walkup = PHL_17[PHL_17['user_type'] == 'Walk-up'].groupby(['date', 'hour'])['bike_id'].nunique()
bike_hourly_demand_walkup = pd.DataFrame(bike_hourly_demand_walkup)

bike_hourly_demand_Indego30 = PHL_17[PHL_17['user_type'] == 'Indego30'].groupby(['date', 'hour'])['bike_id'].nunique()
bike_hourly_demand_Indego30 = pd.DataFrame(bike_hourly_demand_Indego30)

fig, ax = plt.subplots(2,2, figsize=(20,8))

sns.lineplot(x=bike_hourly_demand_walkup.index.get_level_values(1), y=bike_hourly_demand_walkup['bike_id'],ax=ax[0,0])

sns.boxplot(x=bike_hourly_demand_walkup.index.get_level_values(1), y=bike_hourly_demand_walkup['bike_id'],ax=ax[0,1])

sns.lineplot(x=bike_hourly_demand_Indego30.index.get_level_values(1), y=bike_hourly_demand_Indego30['bike_id'],ax=ax[1,0])

sns.boxplot(x=bike_hourly_demand_Indego30.index.get_level_values(1), y=bike_hourly_demand_Indego30['bike_id'],ax=ax[1,1])

ax[0,0].set(xlabel='Hour', ylabel='# of bikes')
ax[0,1].set(xlabel='Hour', ylabel='# of bikes')
ax[1,0].set(xlabel='Hour', ylabel='# of bikes')
ax[1,1].set(xlabel='Hour', ylabel='# of bikes')

fig.subplots_adjust(hspace=.5)

ax[0,0].set_title('Hourly Demand by Walk-up')
ax[0,1].set_title('Hourly Demand by Walk-up')
ax[1,0].set_title('Hourly Demand by Indego30')
ax[1,1].set_title('Hourly Demand by Indego30')

plt.show()

# %% [markdown]
# Let's now apply a simple clustering algorithm, i.e. the **K-Means Algorithm**. But first we need to adapt our dataframe and **normalize**

# %% [markdown]
# To make this an unsupervised learning task we need to drop the label (i.e. user_type). For later checks we save the response as variable y

# %% [markdown]
# For this time, we are only looking at **Indego 365** subscribers and **One Day Pass** customers, i.e. people who are using the bikes frequently as well as people who are using the bikes in their freetime for example

# %%
X = PHL_17[["haversine_km","duration", "net_speed"]][(PHL_17["user_type"] == "One Day Pass") | (PHL_17["user_type"] == "Indego365")]
y = PHL_17[(PHL_17["user_type"] == "One Day Pass") | (PHL_17["user_type"] == "Indego365")]
X.head()
# Out:
#         haversine_km        duration  net_speed
# 279468           NaN 0 days 00:24:00        NaN
# 290510      1.101719 0 days 00:17:00   3.888420
# 290821      1.209120 0 days 00:13:00   5.580555
# 290827      2.402028 0 days 01:06:00   2.183662
# 291465      0.000000 0 days 03:32:00   0.000000

# %%
def td_to_minutes(td):
    return (td.seconds//60)%60

# %%
X["duration_minutes"] = X["duration"].apply(lambda td: td_to_minutes(td))
X.drop("duration", axis=1, inplace=True)

# %%
X.head()
# Out:
#         haversine_km  net_speed  duration_minutes
# 279468           NaN        NaN                24
# 290510      1.101719   3.888420                17
# 290821      1.209120   5.580555                13
# 290827      2.402028   2.183662                 6
# 291465      0.000000   0.000000                32

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

# create a df out of array
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns, index=X.index)
X_scaled
# Out:
# array([[        nan,         nan,  0.75439112],
#        [-0.49975014, -0.80614938,  0.11834155],
#        [-0.38653326, -0.38890174, -0.24511536],
#        ...,
#        [ 0.00842511,  0.57823348, -0.51770803],
#        [-0.49410057,  0.57490556, -0.79030071],
#        [ 0.0266694 ,  0.38849381, -0.42684381]])

# %%
PHL_17_scaled = X_scaled_df
PHL_17_scaled["user_type"] = PHL_17["user_type"]

# %%
sns.pairplot(data=PHL_17_scaled, hue="user_type", palette="magma", markers=["o", "D"], hue_order=["Indego365", "One Day Pass"])

# %% [markdown]
# It looks like the frequent travellers (i.e. **Indego365** subscribers) are traveling **faster** and for a **shorter** time , while occasional users (i.e. **One Day Pass** holders) are traveling **slower** but for a **longer** time. This implies that the One Day Pass is used for **round trips** in particular

# %% [markdown]
# Now with a standard seaborn scatterplot

# %%
X_scaled_df
# Out:
#         haversine_km  net_speed  duration_minutes
# 279468           NaN        NaN          0.754391
# 290510     -0.499750  -0.806149          0.118342
# 290821     -0.386533  -0.388902         -0.245115
# 290827      0.870971  -1.226510         -0.881165
# 291465     -1.661128  -1.764959          1.481305
# ...              ...        ...               ...
# 751779     -1.102386   0.848991         -1.153758
# 751793     -0.967809  -0.548630         -0.699436
# 751804      0.008425   0.578233         -0.517708
# 751822     -0.494101   0.574906         -0.790301
# 751826      0.026669   0.388494         -0.426844
#
# [13168 rows x 3 columns]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize= (16,9))

# use the seaborn hue statement to differentiate the different species
sns.scatterplot(ax=ax, x="haversine_km", y="duration_minutes", 
                data = PHL_17_scaled, hue="user_type", palette="magma", hue_order=["Indego365", "One Day Pass"])

ax.set_xlabel("haversine_km")
ax.set_ylabel("duration_minutes")
ax.set_title("user_types", fontsize=14)
ax.legend(fontsize=12)

plt.show()

# %% [markdown]
# Let's now apply the **K-Means Algorithm** itself

# %%
from sklearn.cluster import KMeans

# %%
IndexList = [np.any(i) for i in np.isnan(X_scaled)]
X_scaled = np.delete(X_scaled, IndexList, axis = 0)

# %%
k_max = 10  # We have 147 datapoints, more than 50 clusters are definitely not reasonable!

clusters = []
losses = []

for k in range(k_max):
    model = KMeans(n_clusters=k+1)
    model.fit(X_scaled)
    clusters.append(k+1)
    losses.append(model.inertia_)

# %%
plt.plot(clusters, losses)
plt.show()

# %%
two_means = KMeans(n_clusters=2)
two_means.fit(X_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
PHL_17_scaled = PHL_17_scaled[~PHL_17_scaled.isna().any(axis=1)]

# %%
numbers = ["zero", "one", "two", "three","four","five"]
PHL_17_scaled["clusters"] = two_means.predict(X_scaled)
PHL_17_scaled["clusters"] = PHL_17_scaled["clusters"].apply(lambda x: numbers[x])
sns.pairplot(data= PHL_17_scaled, hue="clusters")
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/4048629946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PHL_17_scaled["clusters"] = two_means.predict(X_scaled)
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/4048629946.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PHL_17_scaled["clusters"] = PHL_17_scaled["clusters"].apply(lambda x: numbers[x])

# %%
X = PHL_17[['haversine_km', 'duration', 'net_speed','']]
X.drop(PHL_17[PHL_17.net_speed > 20].index, inplace=True)
# Out:
# C:\Users\vigro\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
X["duration_minutes"] = X["duration"].apply(lambda td: td_to_minutes(td))
X.drop("duration", axis=1, inplace=True)
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/325227250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["duration_minutes"] = X["duration"].apply(lambda td: td_to_minutes(td))

# %%
X.head()
# Out:
#    haversine_km  net_speed  duration_minutes
# 0      2.190091  11.945950                11
# 1      3.221661   5.369436                36
# 2      3.221661   5.522848                35
# 3      2.463715  12.318573                12
# 4      0.840301   6.302257                 8

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)

# create a df out of array
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns, index=X.index)
len(X_scaled)
# Out:
# 787997

# %%
PHL_17_scaled = X_scaled_df
PHL_17_scaled["user_type"] = PHL_17["user_type"]

# %%
sns.pairplot(data=PHL_17_scaled, hue="user_type", palette="magma")

# %%
X_scaled_df
# Out:
#         haversine_km  net_speed  duration_minutes user_type
# 0           0.518035   0.883040         -0.305394  Indego30
# 1           1.513683  -0.733898          2.000588   Walk-up
# 2           1.513683  -0.696180          1.908349   Walk-up
# 3           0.782130   0.974655         -0.213154  Indego30
# 4          -0.784751  -0.504550         -0.582112   Walk-up
# ...              ...        ...               ...       ...
# 788899      1.412300  -1.247458          3.937613   Walk-up
# 788900      3.472681   0.039656          2.092828  Indego30
# 788901      1.412300  -1.233054          3.845374   Walk-up
# 788902     -1.595789  -2.054057         -1.227786  Indego30
# 788903     -0.616673   0.083799         -0.674351  Indego30
#
# [787997 rows x 4 columns]

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize= (16,9))

# use the seaborn hue statement to differentiate the different species
sns.scatterplot(ax=ax, x="haversine_km", y="duration_minutes", 
                data = PHL_17_scaled, hue="user_type", palette="magma")

ax.set_xlabel("haversine_km")
ax.set_ylabel("duration_minutes")
ax.set_title("user_types", fontsize=14)
ax.legend(fontsize=12)

plt.show()
# Out:
# C:\Users\vigro\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
IndexList = [np.any(i) for i in np.isnan(X_scaled)]
X_scaled = np.delete(X_scaled, IndexList, axis = 0)
len(X_scaled)
# Out:
# 699548

# %%
k_max = 10 # We have 147 datapoints, more than 50 clusters are definitely not reasonable!

clusters = []
losses = []

for k in range(k_max):
    model = KMeans(n_clusters=k+1)
    model.fit(X_scaled)
    clusters.append(k+1)
    losses.append(model.inertia_)

# %%
plt.plot(clusters, losses)
plt.show()

# %%
six_means = KMeans(n_clusters=6)
six_means.fit(X_scaled)
# Out:
# KMeans(n_clusters=6)

# %%
PHL_17_scaled = PHL_17_scaled[~PHL_17_scaled.isna().any(axis=1)]
PHL_17_scaled
# Out:
#         haversine_km  net_speed  duration_minutes user_type
# 0           0.518035   0.883040         -0.305394  Indego30
# 1           1.513683  -0.733898          2.000588   Walk-up
# 2           1.513683  -0.696180          1.908349   Walk-up
# 3           0.782130   0.974655         -0.213154  Indego30
# 4          -0.784751  -0.504550         -0.582112   Walk-up
# ...              ...        ...               ...       ...
# 788899      1.412300  -1.247458          3.937613   Walk-up
# 788900      3.472681   0.039656          2.092828  Indego30
# 788901      1.412300  -1.233054          3.845374   Walk-up
# 788902     -1.595789  -2.054057         -1.227786  Indego30
# 788903     -0.616673   0.083799         -0.674351  Indego30
#
# [699548 rows x 4 columns]

# %%
numbers = ["zero", "one", "two", "three","four","five", 'six']
PHL_17_scaled["clusters"] = six_means.predict(X_scaled)
PHL_17_scaled["clusters"] = PHL_17_scaled["clusters"].apply(lambda x: numbers[x])
sns.pairplot(data= PHL_17_scaled, hue="clusters")
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/1581404291.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PHL_17_scaled["clusters"] = six_means.predict(X_scaled)
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/1581404291.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PHL_17_scaled["clusters"] = PHL_17_scaled["clusters"].apply(lambda x: numbers[x])

# %% [markdown]
# # 2. Predictive Analytics (Task 2)

# %% [markdown]
# ## 2.1 Feature Engineering/Feature Selection

# %% [markdown]
# Counting the rides per hour

# %%
Features = PHL_17.copy()
Features.head()
# Out:
#            start_time            end_time  start_station_id  end_station_id  \
# 0 2017-01-01 00:05:00 2017-01-01 00:16:00              3046            3041
# 1 2017-01-01 00:21:00 2017-01-01 00:57:00              3110            3054
# 2 2017-01-01 00:22:00 2017-01-01 00:57:00              3110            3054
# 3 2017-01-01 00:27:00 2017-01-01 00:39:00              3041            3005
# 4 2017-01-01 00:28:00 2017-01-01 00:36:00              3047            3124
#
#    bike_id user_type           start_station_name     end_station_name  \
# 0     5347  Indego30                 2nd & Market  Girard Station, MFL
# 1     3364   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 2     2536   Walk-up  Del. River Trail & Penn St.         Rodin Museum
# 3     5176  Indego30          Girard Station, MFL    Welcome Park, NPS
# 4     5370   Walk-up       Independence Mall, NPS     Race Street Pier
#
#          date  hour  ...  month        duration  start_lat  start_lon  \
# 0  2017-01-01     0  ...      1 0 days 00:11:00  39.950119 -75.144722
# 1  2017-01-01     0  ...      1 0 days 00:36:00  39.961750 -75.136414
# 2  2017-01-01     0  ...      1 0 days 00:35:00  39.961750 -75.136414
# 3  2017-01-01     0  ...      1 0 days 00:12:00  39.968491 -75.135460
# 4  2017-01-01     0  ...      1 0 days 00:08:00  39.950710 -75.149208
#
#      end_lat    end_lon    start_coordinates      end_coordinates  \
# 0  39.968491 -75.135460  (39.9501, -75.1447)  (39.9685, -75.1355)
# 1  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 2  39.962502 -75.174202  (39.9618, -75.1364)  (39.9625, -75.1742)
# 3  39.947330 -75.144028  (39.9685, -75.1355)   (39.9473, -75.144)
# 4  39.952950 -75.139793  (39.9507, -75.1492)   (39.953, -75.1398)
#
#   haversine_km  net_speed
# 0     2.190091  11.945950
# 1     3.221661   5.369436
# 2     3.221661   5.522848
# 3     2.463715  12.318573
# 4     0.840301   6.302257
#
# [5 rows x 21 columns]

# %%
date1 = pd.datetime(year=2017, month=1, day=1, hour = 1)
date2 = pd.datetime(year=2017, month=1, day=1, hour = 2)

len(Features[(Features["start_time"] >= date1) & (Features["start_time"] < date2)])
# Out:
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/4057109128.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date1 = pd.datetime(year=2017, month=1, day=1, hour = 1)
# C:\Users\vigro\AppData\Local\Temp/ipykernel_20992/4057109128.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   date2 = pd.datetime(year=2017, month=1, day=1, hour = 2)
# 25

# %% [markdown]
# Between 1am and 2am on January 1st, 25 rides were taken

# %%
date_index = pd.to_timedelta(np.arange(8760), 'H')

Features = pd.DataFrame(index = date_index)

Features["demand"] = 0

Features = PHL_17.set_index("start_time")
Features = Features.resample('H').count()  #Aggregating hourly

Features.rename(columns = {"end_time": "rides"}, inplace = True)

# %%
Features.head()
# Out:
#                      rides  start_station_id  end_station_id  bike_id  \
# start_time
# 2017-01-01 00:00:00     21                21              21       21
# 2017-01-01 01:00:00     25                25              25       25
# 2017-01-01 02:00:00     17                17              17       17
# 2017-01-01 03:00:00      5                 5               5        5
# 2017-01-01 04:00:00      4                 4               4        4
#
#                      user_type  start_station_name  end_station_name  date  \
# start_time
# 2017-01-01 00:00:00         21                  21                21    21
# 2017-01-01 01:00:00         25                  25                25    25
# 2017-01-01 02:00:00         17                  17                17    17
# 2017-01-01 03:00:00          5                   5                 5     5
# 2017-01-01 04:00:00          4                   4                 4     4
#
#                      hour  weekday  month  duration  start_lat  start_lon  \
# start_time
# 2017-01-01 00:00:00    21       21     21        21         21         21
# 2017-01-01 01:00:00    25       25     25        25         25         25
# 2017-01-01 02:00:00    17       17     17        17         17         17
# 2017-01-01 03:00:00     5        5      5         5          5          5
# 2017-01-01 04:00:00     4        4      4         4          4          4
#
#                      end_lat  end_lon  start_coordinates  end_coordinates  \
# start_time
# 2017-01-01 00:00:00       21       21                 21               21
# 2017-01-01 01:00:00       25       25                 25               25
# 2017-01-01 02:00:00       17       17                 17               17
# 2017-01-01 03:00:00        5        5                  5                5
# 2017-01-01 04:00:00        4        4                  4                4
#
#                      haversine_km  net_speed
# start_time
# 2017-01-01 00:00:00            21         21
# 2017-01-01 01:00:00            25         25
# 2017-01-01 02:00:00            17         17
# 2017-01-01 03:00:00             5          5
# 2017-01-01 04:00:00             4          4

# %% [markdown]
# Since the other columns do not make sense to be aggregated, we drop them

# %%
Features = Features[['rides']]

# %%
Features.head()
# Out:
#                      rides
# start_time
# 2017-01-01 00:00:00     21
# 2017-01-01 01:00:00     25
# 2017-01-01 02:00:00     17
# 2017-01-01 03:00:00      5
# 2017-01-01 04:00:00      4

# %% [markdown]
# Creating a new column that contains the **number of rides from the previous hour**

# %%
Features["rides_last_hour"] = 0
x = Features.iloc[0]["rides"]
for i in Features.index:
    Features.loc[i,"rides_last_hour"] = x
    x = Features.loc[i]["rides"]

# %%
Features.head()
# Out:
#                      rides  rides_last_hour
# start_time
# 2017-01-01 00:00:00     21               21
# 2017-01-01 01:00:00     25               21
# 2017-01-01 02:00:00     17               25
# 2017-01-01 03:00:00      5               17
# 2017-01-01 04:00:00      4                5

# %% [markdown]
# Creating the **previously dropped features in a new fashion**

# %%
def is_weekday (ts):
    if (ts <= 4):
        return 1
    else: 
        return 0

# %%
Features['hour'] = Features.index.hour
Features['weekday'] = Features.index.weekday
Features['month'] = Features.index.month
Features["is_weekday"] = Features["weekday"].apply(lambda ts: is_weekday (ts))
# Could also define functions in order to map it to the dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13764/871638200.py in <module>
# ----> 1 Features['hour'] = Features.index.hour
#       2 Features['weekday'] = Features.index.weekday
#       3 Features['month'] = Features.index.month
#       4 Features["is_weekday"] = Features["weekday"].apply(lambda ts: is_weekday (ts))
#       5 # Could also define functions in order to map it to the dataframe
#
# NameError: name 'Features' is not defined

# %%
Features[Features["is_weekday"] == 1]

# %%
Features.head()

# %% [markdown]
# Adding the **average temperature (hourly)** and **precipitation** from the weather dataset

# %%
Features = Features.join(PHL_weather_17, on="start_time")
Features.drop(columns = "max_temp", inplace = True)
Features.drop(columns = "min_temp", inplace = True)

# %%
Features.head()

# %% [markdown]
# Plotting a **covariance matrix** and a **correlation matrix** of the newly defined features

# %%
covariance = Features.cov()
covariance

# %% [markdown]
# - If it rains (precip = 1), less rides are taken (negative covariance, opposing values)
# - The higher the temperature, the more rides are taken (positive covariance)
# - If the day is a weekday (is_weekday = 1), more rides are taken (positive covariance)

# %%
correlation = Features.corr()
correlation

# %% [markdown]
# Korrelation normiert die Kovarianz und gibt Auskunft über Stärke des linearen Zusammenhangs

# %%
sns.heatmap(correlation, xticklabels=correlation.columns,yticklabels=correlation.columns, cmap="Greens")
